# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img1=cv2.imread('mountains1.jpg')
img2=cv2.imread('mountains2.jpg')

# %%
img2 = cv2.resize(img2,(350,168))
img1= cv2.resize(img1,(350,168))

# %%
img2.shape
# Out:
# (168, 350, 3)

# %%
img1.shape
# Out:
# (168, 350, 3)

# %%
new_img=img1-img2

# %%
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x168 at 0x7FD4AB8DAD30>

# %%
new_img1=img2-img1

# %%
cv2_imshow(new_img1)
# Out:
# <PIL.Image.Image image mode=RGB size=350x168 at 0x7FD4AB86A080>

# %%
new_sum=img1+img2

# %%
cv2_imshow(new_sum)
# Out:
# <PIL.Image.Image image mode=RGB size=350x168 at 0x7FD4AB86C198>
